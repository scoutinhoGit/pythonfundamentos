# %%
import pandas as pd

# %%
# !pip freeze | grep pandas
# Out:
# pandas==0.25.3

# %%
df = pd.read_csv('Aulas/Dados/campeonato-brasileiro-full.csv',encoding='utf-8',sep=',',header=0 , nrows=15, usecols=['Horário','Dia','Data','Clube 1','Clube 2','Vencedor','Rodada','Arena'])

# %%
df
# Out:
#    Horário           Dia        Data        Clube 1       Clube 2  \
# 0    16h00        Sábado  2000-07-29     Fluminense         Bahia
# 1    16h00        Sábado  2000-07-29          Vasco         Sport
# 2    16h00        Sábado  2000-07-29        Vitória     Palmeiras
# 3    17h00       Domingo  2000-07-30    Botafogo-RJ   Atlético-MG
# 4    18h30       Domingo  2000-07-30      Juventude      Flamengo
# 5    16h00       Domingo  2000-07-30        Guarani    Santa Cruz
# 6    17h00       Domingo  2000-07-30       Cruzeiro  Athlético-PR
# 7    16h00       Domingo  2000-07-30     América-MG          Gama
# 8    18h30       Domingo  2000-07-30          Goiás   Corinthians
# 9    20h30  Quarta-feira  2000-08-02       Coritiba         Sport
# 10   20h30  Quarta-feira  2000-08-02          Bahia  Athlético-PR
# 11   21h40  Quarta-feira  2000-08-02       Flamengo        Grêmio
# 12   20h30  Quarta-feira  2000-08-02           Gama    Fluminense
# ...

# %%
df = pd.read_csv('Aulas/Dados/campeonato-brasileiro-full.csv',encoding='utf-8',sep=',',header=0)

# %%
#amostra de linhas (default 5)
df.head()
# Out:
#   Horário      Dia        Data      Clube 1      Clube 2    Vencedor  \
# 0   16h00   Sábado  2000-07-29   Fluminense        Bahia  Fluminense
# 1   16h00   Sábado  2000-07-29        Vasco        Sport       Sport
# 2   16h00   Sábado  2000-07-29      Vitória    Palmeiras     Vitória
# 3   17h00  Domingo  2000-07-30  Botafogo-RJ  Atlético-MG           -
# 4   18h30  Domingo  2000-07-30    Juventude     Flamengo           -
#
#       Rodada           Arena  Clube 1 Gols  Clube 2 Gols Clube 1 Estado  \
# 0  1ª Rodada        Maracanã             2             0             RJ
# 1  1ª Rodada    São Januário             0             2             RJ
# 2  1ª Rodada        Barradão             4             1             ES
# 3  1ª Rodada    Caio Martins             0             0             RJ
# 4  1ª Rodada  Alfredo Jaconi             1             1             RS
#
#   Clube 2 Estado Estado Clube Vencedor
# 0             BA                    RJ
# ...

# %%
#dimensoes
df.shape
# Out:
# (7939, 13)

# %%
df2=df

# %%
df2.head(2)
# Out:
#   Horário     Dia        Data     Clube 1 Clube 2    Vencedor     Rodada  \
# 0   16h00  Sábado  2000-07-29  Fluminense   Bahia  Fluminense  1ª Rodada
# 1   16h00  Sábado  2000-07-29       Vasco   Sport       Sport  1ª Rodada
#
#           Arena  Clube 1 Gols  Clube 2 Gols Clube 1 Estado Clube 2 Estado  \
# 0      Maracanã             2             0             RJ             BA
# 1  São Januário             0             2             RJ             PE
#
#   Estado Clube Vencedor
# 0                    RJ
# 1                    PE

# %%
# dropa as primeiras 2 linhas
df2 = df2.drop([0,2])

# %%
df2.head(2)
# Out:
#   Horário      Dia        Data      Clube 1      Clube 2 Vencedor     Rodada  \
# 1   16h00   Sábado  2000-07-29        Vasco        Sport    Sport  1ª Rodada
# 3   17h00  Domingo  2000-07-30  Botafogo-RJ  Atlético-MG        -  1ª Rodada
#
#           Arena  Clube 1 Gols  Clube 2 Gols Clube 1 Estado Clube 2 Estado  \
# 1  São Januário             0             2             RJ             PE
# 3  Caio Martins             0             0             RJ             MG
#
#   Estado Clube Vencedor
# 1                    PE
# 3                Empate

# %%
df.to_csv('resultatus.csv')

# %%
df2.columns
# Out:
# Index(['Horário', 'Dia', 'Data', 'Clube 1', 'Clube 2', 'Vencedor', 'Rodada',
#        'Arena', 'Clube 1 Gols', 'Clube 2 Gols', 'Clube 1 Estado',
#        'Clube 2 Estado', 'Estado Clube Vencedor'],
#       dtype='object')

# %%
df.apply(lambda x: x.replace('Fluminense','Apito Amigo') )
# Out:
#      Horário      Dia        Data        Clube 1      Clube 2       Vencedor  \
# 0      16h00   Sábado  2000-07-29    Apito Amigo        Bahia    Apito Amigo
# 1      16h00   Sábado  2000-07-29          Vasco        Sport          Sport
# 2      16h00   Sábado  2000-07-29        Vitória    Palmeiras        Vitória
# 3      17h00  Domingo  2000-07-30    Botafogo-RJ  Atlético-MG              -
# 4      18h30  Domingo  2000-07-30      Juventude     Flamengo              -
# ...      ...      ...         ...            ...          ...            ...
# 7934   17:00  Domingo  2019-12-08          Goiás       Grêmio          Goiás
# 7935   17:00  Domingo  2019-12-08  Internacional  Atlético-MG  Internacional
# 7936   17:00  Domingo  2019-12-08       Cruzeiro    Palmeiras      Palmeiras
# 7937   17:00  Domingo  2019-12-08         Santos     Flamengo         Santos
# 7938   17:00  Domingo  2019-12-08            CSA    São Paulo      São Paulo
#
# ...

# %%
#df2.drop('Horário',axis=1)
df2.drop(0,axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-0acbd6e26a90> in <module>
#       1 #df2.drop('Horário',axis=1)
# ----> 2 df2.drop(0,axis=0)
#
# ~/pythonfundamentos/venv/lib/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4115             level=level,
#    4116             inplace=inplace,
# -> 4117             errors=errors,
#    4118         )
#    4119
#
# ~/pythonfundamentos/venv/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ...
